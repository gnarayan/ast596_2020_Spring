# %% [markdown]
# ## HW 1

# %% [markdown]
# # Question 1

# %%
from astropy.io import fits
import seaborn as sns
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
from scipy.stats import linregress
# %matplotlib inline

# %%
#Opening Files
g1 =fits.open("C:/Users/Pas/Downloads/HLC.RA_20_to_21.fits.gz")
g2 =fits.open("C:/Users/Pas/Downloads/HLC.RA_21_to_22.fits.gz")
g3 =fits.open("C:/Users/Pas/Downloads/HLC.RA_22_to_23.fits.gz")
g4 =fits.open("C:/Users/Pas/Downloads/HLC.RA_23_to_24.fits.gz")
g5 =fits.open("C:/Users/Pas/Downloads/HLC.RA_00_to_01.fits.gz")
g6 =fits.open("C:/Users/Pas/Downloads/HLC.RA_01_to_02.fits.gz")
g7 =fits.open("C:/Users/Pas/Downloads/HLC.RA_02_to_03.fits.gz")
g8 =fits.open("C:/Users/Pas/Downloads/HLC.RA_03_to_04.fits.gz")

# %%
#open through HDUlist instead?
#CHECK all DATA FOR OUTLIERS

# %%
#Extracting and filtering data
g1_data = g1[1].data
g1_stars = g1_data[(g1_data['Mean_Object_Type'])>5]
g1_galaxies = g1_data[(g1_data['Mean_Object_Type'])<=5]
g2_data = g2[1].data
g2_stars = g2_data[(g2_data['Mean_Object_Type'])>5]
g2_galaxies = g2_data[(g2_data['Mean_Object_Type'])<=5]
g3_data = g3[1].data
g3_stars = g3_data[(g3_data['Mean_Object_Type'])>5]
g3_galaxies = g3_data[(g3_data['Mean_Object_Type'])<=5]
g4_data = g4[1].data
g4_stars = g4_data[(g4_data['Mean_Object_Type'])>5]
g4_galaxies = g4_data[(g4_data['Mean_Object_Type'])<=5]
g5_data = g5[1].data
g5_stars = g5_data[(g5_data['Mean_Object_Type'])>5]
g5_galaxies = g5_data[(g5_data['Mean_Object_Type'])<=5]
g6_data = g6[1].data
g6_stars = g6_data[(g6_data['Mean_Object_Type'])>5]
g6_galaxies = g6_data[(g6_data['Mean_Object_Type'])<=5]
g7_data = g7[1].data
g7_stars = g7_data[(g7_data['Mean_Object_Type'])>5]
g7_galaxies = g7_data[(g7_data['Mean_Object_Type'])<=5]
g8_data = g8[1].data
g8_stars = g8_data[(g8_data['Mean_Object_Type'])>5]
g8_galaxies = g8_data[(g8_data['Mean_Object_Type'])<=5]

# %% [markdown]
# # Stars

# %%
#plotting-each vector is in form [u, g, r, i, z]-need to seperate them
#1st
#stars
stars1_array = np.zeros((len(g1_stars["MEAN_PSFMAG"]), 3))
for n in range(0,len(g1_stars["MEAN_PSFMAG"])):
    stars1_array[n,0] = (g1_stars["MEAN_PSFMAG"])[n,2]
    stars1_array[n,1] = (g1_stars["MEAN_PSFMAG"])[n,1]
    stars1_array[n,2] = (g1_stars["MEAN_PSFMAG"])[n,3]

#galaxies
galaxies1_array = np.zeros((len(g1_galaxies["MEAN_PSFMAG"]), 3))
for n in range(0,len(g1_galaxies["MEAN_PSFMAG"])):
    galaxies1_array[n][0] = (g1_galaxies["MEAN_PSFMAG"])[n,2]
    galaxies1_array[n][1] = (g1_galaxies["MEAN_PSFMAG"])[n,1]
    galaxies1_array[n][2] = (g1_galaxies["MEAN_PSFMAG"])[n,3]
    
#2nd
#stars
stars2_array = np.zeros((len(g2_stars["MEAN_PSFMAG"]), 3))
for n in range(0,len(g2_stars["MEAN_PSFMAG"])):
    stars2_array[n,0] = (g2_stars["MEAN_PSFMAG"])[n,2]
    stars2_array[n,1] = (g2_stars["MEAN_PSFMAG"])[n,1]
    stars2_array[n,2] = (g2_stars["MEAN_PSFMAG"])[n,3]

#galaxies
galaxies2_array = np.zeros((len(g2_galaxies["MEAN_PSFMAG"]), 3))
for n in range(0,len(g2_galaxies["MEAN_PSFMAG"])):
    galaxies2_array[n][0] = (g2_galaxies["MEAN_PSFMAG"])[n,2]
    galaxies2_array[n][1] = (g2_galaxies["MEAN_PSFMAG"])[n,1]
    galaxies2_array[n][2] = (g2_galaxies["MEAN_PSFMAG"])[n,3]

#3rd
#stars
stars3_array = np.zeros((len(g3_stars["MEAN_PSFMAG"]), 3))
for n in range(0,len(g3_stars["MEAN_PSFMAG"])):
    stars3_array[n,0] = (g3_stars["MEAN_PSFMAG"])[n,2]
    stars3_array[n,1] = (g3_stars["MEAN_PSFMAG"])[n,1]
    stars3_array[n,2] = (g3_stars["MEAN_PSFMAG"])[n,3]

#galaxies
galaxies3_array = np.zeros((len(g3_galaxies['MEAN_PSFMAG']), 3))
for n in range(0,len(g3_galaxies["MEAN_PSFMAG"])):
    galaxies3_array[n][0] = (g3_galaxies["MEAN_PSFMAG"])[n,2]
    galaxies3_array[n][1] = (g3_galaxies["MEAN_PSFMAG"])[n,1]
    galaxies3_array[n][2] = (g3_galaxies["MEAN_PSFMAG"])[n,3]
    
#4th
#stars
stars4_array = np.zeros((len(g4_stars["MEAN_PSFMAG"]), 3))
for n in range(0,len(g4_stars["MEAN_PSFMAG"])):
    stars4_array[n,0] = (g4_stars["MEAN_PSFMAG"])[n,2]
    stars4_array[n,1] = (g4_stars["MEAN_PSFMAG"])[n,1]
    stars4_array[n,2] = (g4_stars["MEAN_PSFMAG"])[n,3]
    
#galaxies
galaxies4_array = np.zeros((len(g4_galaxies['MEAN_PSFMAG']), 3))
for n in range(0,len(g4_galaxies["MEAN_PSFMAG"])):
    galaxies4_array[n][0] = (g4_galaxies["MEAN_PSFMAG"])[n,2]
    galaxies4_array[n][1] = (g4_galaxies["MEAN_PSFMAG"])[n,1]
    galaxies4_array[n][2] = (g4_galaxies["MEAN_PSFMAG"])[n,3]
    
#5th
#stars
stars5_array = np.zeros((len(g5_stars["MEAN_PSFMAG"]), 3))
for n in range(0,len(g5_stars["MEAN_PSFMAG"])):
    stars5_array[n,0] = (g5_stars["MEAN_PSFMAG"])[n,2]
    stars5_array[n,1] = (g5_stars["MEAN_PSFMAG"])[n,1]
    stars5_array[n,2] = (g5_stars["MEAN_PSFMAG"])[n,3]
    
#galaxies
galaxies5_array = np.zeros((len(g5_galaxies['MEAN_PSFMAG']), 3))
for n in range(0,len(g5_galaxies["MEAN_PSFMAG"])):
    galaxies5_array[n][0] = (g5_galaxies["MEAN_PSFMAG"])[n,2]
    galaxies5_array[n][1] = (g5_galaxies["MEAN_PSFMAG"])[n,1]
    galaxies5_array[n][2] = (g5_galaxies["MEAN_PSFMAG"])[n,3]

#6th
#stars
stars6_array = np.zeros((len(g6_stars["MEAN_PSFMAG"]), 3))
for n in range(0,len(g6_stars["MEAN_PSFMAG"])):
    stars6_array[n,0] = (g6_stars["MEAN_PSFMAG"])[n,2]
    stars6_array[n,1] = (g6_stars["MEAN_PSFMAG"])[n,1]
    stars6_array[n,2] = (g6_stars["MEAN_PSFMAG"])[n,3]
    
#galaxies
galaxies6_array = np.zeros((len(g6_galaxies['MEAN_PSFMAG']), 3))
for n in range(0,len(g6_galaxies["MEAN_PSFMAG"])):
    galaxies6_array[n][0] = (g6_galaxies["MEAN_PSFMAG"])[n,2]
    galaxies6_array[n][1] = (g6_galaxies["MEAN_PSFMAG"])[n,1]
    galaxies6_array[n][2] = (g6_galaxies["MEAN_PSFMAG"])[n,3]

#7th
#stars
stars7_array = np.zeros((len(g7_stars["MEAN_PSFMAG"]), 3))
for n in range(0,len(g7_stars["MEAN_PSFMAG"])):
    stars7_array[n,0] = (g7_stars["MEAN_PSFMAG"])[n,2]
    stars7_array[n,1] = (g7_stars["MEAN_PSFMAG"])[n,1]
    stars7_array[n,2] = (g7_stars["MEAN_PSFMAG"])[n,3]

#galaxies
galaxies7_array = np.zeros((len(g7_galaxies['MEAN_PSFMAG']), 3))
for n in range(0,len(g7_galaxies["MEAN_PSFMAG"])):
    galaxies7_array[n][0] = (g7_galaxies["MEAN_PSFMAG"])[n,2]
    galaxies7_array[n][1] = (g7_galaxies["MEAN_PSFMAG"])[n,1]
    galaxies7_array[n][2] = (g7_galaxies["MEAN_PSFMAG"])[n,3]

#8th
#stars
stars8_array = np.zeros((len(g8_stars['MEAN_PSFMAG']), 3))
for n in range(0,len(g8_stars["MEAN_PSFMAG"])):
    stars8_array[n,0] = (g8_stars["MEAN_PSFMAG"])[n,2]
    stars8_array[n,1] = (g8_stars["MEAN_PSFMAG"])[n,1]
    stars8_array[n,2] = (g8_stars["MEAN_PSFMAG"])[n,3]

#galaxies
galaxies8_array = np.zeros((len(g8_galaxies['MEAN_PSFMAG']), 3))
for n in range(0,len(g8_galaxies["MEAN_PSFMAG"])):
    galaxies8_array[n][0] = (g8_galaxies["MEAN_PSFMAG"])[n,2]
    galaxies8_array[n][1] = (g8_galaxies["MEAN_PSFMAG"])[n,1]
    galaxies8_array[n][2] = (g8_galaxies["MEAN_PSFMAG"])[n,3]

# %%
#3 panel plots
#1st 
#stars
data1_stars = {'g-i': (stars1_array[:,1] - stars1_array[:,2]), "r":stars1_array[:,0]}
df1_stars = pd.DataFrame(data = data1_stars)
df1_stars["RA_PM"] = g1_stars["RA_PM"]
df1_stars["DEC_PM"] = g1_stars["DEC_PM"]

#RA_BIN
df1_stars["RA_PM"] = g1_stars["RA_PM"]
RA_PM_BIN = []
q1 = np.quantile(df1_stars["RA_PM"], .25, axis = None)
q2 = np.quantile(df1_stars["RA_PM"], .50, axis = None)
q3 = np.quantile(df1_stars["RA_PM"], .75, axis = None)

for n in range(0,len(df1_stars["RA_PM"])):
    if (df1_stars["RA_PM"])[n] <= q1:
        RA_PM_BIN.append(1)
    elif ((df1_stars["RA_PM"])[n] > q1) and ((df1_stars["RA_PM"])[n] <= q2):
        RA_PM_BIN.append(2)
    elif ((df1_stars["RA_PM"][n]) > q2) and ((df1_stars["RA_PM"])[n] <= q3):
        RA_PM_BIN.append(3)
    else:
        RA_PM_BIN.append(4)

df1_stars["RA_PM_BINNED"] = RA_PM_BIN

#DEC_BIN
df1_stars["DEC_PM"] = g1_stars["DEC_PM"]
DEC_PM_BIN = []
q1 = np.quantile(df1_stars["DEC_PM"], .25, axis = None)
q2 = np.quantile(df1_stars["DEC_PM"], .50, axis = None)
q3 = np.quantile(df1_stars["DEC_PM"], .75, axis = None)

for n in range(0,len(df1_stars["DEC_PM"])):
    if (df1_stars["DEC_PM"])[n] <= q1:
        DEC_PM_BIN.append(1)
    elif ((df1_stars["DEC_PM"])[n] > q1) and ((df1_stars["DEC_PM"])[n] <= q2):
        DEC_PM_BIN.append(2)
    elif ((df1_stars["DEC_PM"][n]) > q2) and ((df1_stars["DEC_PM"])[n] <= q3):
        DEC_PM_BIN.append(3)
    else:
        DEC_PM_BIN.append(4)

df1_stars["DEC_PM_BINNED"] = DEC_PM_BIN

# %%
#almost got it-need to make panels bigger, incorporate bivariate with first 
#left - r vs (g-i) color coded by density + bivariate distributions
fig, axs = plt.subplots(ncols=3)
sns.jointplot(x='g-i', y='r', data=df1_stars[::100], kind='kde', color="pink", xlim=(-1,4), ylim=(15,24), ax=axs[0]).plot_joint(sns.kdeplot, zorder=0, n_levels=3, color="pink")
#middle and right-color coded by dec, ra - "RA_PM", "DEC_PM" 
#sns.jointplot(x='g-i', y='r', data=df1_stars[::100], kind='reg', xlim=(-5,5), ylim=(13,24))
sns.scatterplot(x='g-i', y='r', data=df1_stars[::100], hue="RA_PM_BINNED", ax=axs[1])
#sns.jointplot(x='g-i', y='r', data=df1_stars[::100], kind='reg', xlim=(-5,5), ylim=(13,24))
sns.scatterplot(x='g-i', y='r', data=df1_stars[::100], hue="DEC_PM_BINNED", ax=axs[2])
# Out:
# C:\Users\Pas\Miniconda3\envs\fds\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#3 panel plots
#2nd 
#stars
data2_stars = {'g-i': (stars2_array[:,1] - stars2_array[:,2]), "r":stars2_array[:,0]}
df2_stars = pd.DataFrame(data = data2_stars)
df2_stars["RA_PM"] = g2_stars["RA_PM"]
df2_stars["DEC_PM"] = g2_stars["DEC_PM"]

#RA_BIN
df2_stars["RA_PM"] = g2_stars["RA_PM"]
RA_PM_BIN = []
q1 = np.quantile(df2_stars["RA_PM"], .25, axis = None)
q2 = np.quantile(df2_stars["RA_PM"], .50, axis = None)
q3 = np.quantile(df2_stars["RA_PM"], .75, axis = None)

for n in range(0,len(df2_stars["RA_PM"])):
    if (df2_stars["RA_PM"])[n] <= q1:
        RA_PM_BIN.append(1)
    elif ((df2_stars["RA_PM"])[n] > q1) and ((df2_stars["RA_PM"])[n] <= q2):
        RA_PM_BIN.append(2)
    elif ((df2_stars["RA_PM"][n]) > q2) and ((df2_stars["RA_PM"])[n] <= q3):
        RA_PM_BIN.append(3)
    else:
        RA_PM_BIN.append(4)

df2_stars["RA_PM_BINNED"] = RA_PM_BIN

#DEC_BIN
df2_stars["DEC_PM"] = g2_stars["DEC_PM"]
DEC_PM_BIN = []
q1 = np.quantile(df2_stars["DEC_PM"], .25, axis = None)
q2 = np.quantile(df2_stars["DEC_PM"], .50, axis = None)
q3 = np.quantile(df2_stars["DEC_PM"], .75, axis = None)

for n in range(0,len(df2_stars["DEC_PM"])):
    if (df2_stars["DEC_PM"])[n] <= q1:
        DEC_PM_BIN.append(1)
    elif ((df2_stars["DEC_PM"])[n] > q1) and ((df2_stars["DEC_PM"])[n] <= q2):
        DEC_PM_BIN.append(2)
    elif ((df2_stars["DEC_PM"][n]) > q2) and ((df2_stars["DEC_PM"])[n] <= q3):
        DEC_PM_BIN.append(3)
    else:
        DEC_PM_BIN.append(4)

df2_stars["DEC_PM_BINNED"] = DEC_PM_BIN

# %%
#almost got it-need to make panels bigger, incorporate bivariate with first 
#left - r vs (g-i) color coded by density + bivariate distributions
fig, axs = plt.subplots(ncols=3)
sns.jointplot(x='g-i', y='r', data=df2_stars[::100], kind='kde', color="pink", xlim=(-1,4), ylim=(15,24), ax=axs[0]).plot_joint(sns.kdeplot, zorder=0, n_levels=3, color="pink")
#middle and right-color coded by dec, ra - "RA_PM", "DEC_PM" 
#sns.jointplot(x='g-i', y='r', data=df2_stars[::100], kind='reg', xlim=(-5,5), ylim=(13,24))
sns.scatterplot(x='g-i', y='r', data=df2_stars[::100], hue="RA_PM_BINNED", ax=axs[1])
#sns.jointplot(x='g-i', y='r', data=df2_stars[::100], kind='reg', xlim=(-5,5), ylim=(13,24))
sns.scatterplot(x='g-i', y='r', data=df2_stars[::100], hue="DEC_PM_BINNED", ax=axs[2])
# Out:
# C:\Users\Pas\Miniconda3\envs\fds\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#3 panel plots
#3rd 
#stars
data3_stars = {'g-i': (stars3_array[:,1] - stars3_array[:,2]), "r":stars3_array[:,0]}
df3_stars = pd.DataFrame(data = data3_stars)
df3_stars["RA_PM"] = g3_stars["RA_PM"]
df3_stars["DEC_PM"] = g3_stars["DEC_PM"]

#RA_BIN
df3_stars["RA_PM"] = g3_stars["RA_PM"]
RA_PM_BIN = []
q1 = np.quantile(df3_stars["RA_PM"], .25, axis = None)
q2 = np.quantile(df3_stars["RA_PM"], .50, axis = None)
q3 = np.quantile(df3_stars["RA_PM"], .75, axis = None)

for n in range(0,len(df3_stars["RA_PM"])):
    if (df3_stars["RA_PM"])[n] <= q1:
        RA_PM_BIN.append(1)
    elif ((df3_stars["RA_PM"])[n] > q1) and ((df3_stars["RA_PM"])[n] <= q2):
        RA_PM_BIN.append(2)
    elif ((df3_stars["RA_PM"][n]) > q2) and ((df3_stars["RA_PM"])[n] <= q3):
        RA_PM_BIN.append(3)
    else:
        RA_PM_BIN.append(4)

df3_stars["RA_PM_BINNED"] = RA_PM_BIN

#DEC_BIN
df3_stars["DEC_PM"] = g3_stars["DEC_PM"]
DEC_PM_BIN = []
q1 = np.quantile(df3_stars["DEC_PM"], .25, axis = None)
q2 = np.quantile(df3_stars["DEC_PM"], .50, axis = None)
q3 = np.quantile(df3_stars["DEC_PM"], .75, axis = None)

for n in range(0,len(df3_stars["DEC_PM"])):
    if (df3_stars["DEC_PM"])[n] <= q1:
        DEC_PM_BIN.append(1)
    elif ((df3_stars["DEC_PM"])[n] > q1) and ((df3_stars["DEC_PM"])[n] <= q2):
        DEC_PM_BIN.append(2)
    elif ((df3_stars["DEC_PM"][n]) > q2) and ((df3_stars["DEC_PM"])[n] <= q3):
        DEC_PM_BIN.append(3)
    else:
        DEC_PM_BIN.append(4)

df3_stars["DEC_PM_BINNED"] = DEC_PM_BIN

# %%
#almost got it-need to make panels bigger, incorporate bivariate with first 
#left - r vs (g-i) color coded by density + bivariate distributions
fig, axs = plt.subplots(ncols=3)
sns.jointplot(x='g-i', y='r', data=df3_stars[::100], kind='kde', color="pink", xlim=(-1,4), ylim=(14,24), ax=axs[0]).plot_joint(sns.kdeplot, zorder=0, n_levels=3, color="pink")
#middle and right-color coded by dec, ra - "RA_PM", "DEC_PM" 
#sns.jointplot(x='g-i', y='r', data=df3_stars[::100], kind='reg', xlim=(-5,5), ylim=(13,24))
sns.scatterplot(x='g-i', y='r', data=df3_stars[::100], hue="RA_PM_BINNED", ax=axs[1])
#sns.jointplot(x='g-i', y='r', data=df3_stars[::100], kind='reg', xlim=(-5,5), ylim=(13,24))
sns.scatterplot(x='g-i', y='r', data=df3_stars[::100], hue="DEC_PM_BINNED", ax=axs[2])
# Out:
# C:\Users\Pas\Miniconda3\envs\fds\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#3 panel plots
#4th 
#stars
data4_stars = {'g-i': (stars4_array[:,1] - stars4_array[:,2]), "r":stars4_array[:,0]}
df4_stars = pd.DataFrame(data = data4_stars)
df4_stars["RA_PM"] = g4_stars["RA_PM"]
df4_stars["DEC_PM"] = g4_stars["DEC_PM"]

#RA_BIN
df4_stars["RA_PM"] = g4_stars["RA_PM"]
RA_PM_BIN = []
q1 = np.quantile(df4_stars["RA_PM"], .25, axis = None)
q2 = np.quantile(df4_stars["RA_PM"], .50, axis = None)
q3 = np.quantile(df4_stars["RA_PM"], .75, axis = None)

for n in range(0,len(df4_stars["RA_PM"])):
    if (df4_stars["RA_PM"])[n] <= q1:
        RA_PM_BIN.append(1)
    elif ((df4_stars["RA_PM"])[n] > q1) and ((df4_stars["RA_PM"])[n] <= q2):
        RA_PM_BIN.append(2)
    elif ((df4_stars["RA_PM"][n]) > q2) and ((df4_stars["RA_PM"])[n] <= q3):
        RA_PM_BIN.append(3)
    else:
        RA_PM_BIN.append(4)

df4_stars["RA_PM_BINNED"] = RA_PM_BIN

#DEC_BIN
df4_stars["DEC_PM"] = g4_stars["DEC_PM"]
DEC_PM_BIN = []
q1 = np.quantile(df4_stars["DEC_PM"], .25, axis = None)
q2 = np.quantile(df4_stars["DEC_PM"], .50, axis = None)
q3 = np.quantile(df4_stars["DEC_PM"], .75, axis = None)

for n in range(0,len(df4_stars["DEC_PM"])):
    if (df4_stars["DEC_PM"])[n] <= q1:
        DEC_PM_BIN.append(1)
    elif ((df4_stars["DEC_PM"])[n] > q1) and ((df4_stars["DEC_PM"])[n] <= q2):
        DEC_PM_BIN.append(2)
    elif ((df4_stars["DEC_PM"][n]) > q2) and ((df4_stars["DEC_PM"])[n] <= q3):
        DEC_PM_BIN.append(3)
    else:
        DEC_PM_BIN.append(4)

df4_stars["DEC_PM_BINNED"] = DEC_PM_BIN

# %%
#almost got it-need to make panels bigger, incorporate bivariate with first 
#left - r vs (g-i) color coded by density + bivariate distributions
fig, axs = plt.subplots(ncols=3)
sns.jointplot(x='g-i', y='r', data=df4_stars[::100], kind='kde', color="pink", xlim=(-2,4), ylim=(14,24), ax=axs[0]).plot_joint(sns.kdeplot, zorder=0, n_levels=3, color="pink")
#middle and right-color coded by dec, ra - "RA_PM", "DEC_PM" 
#sns.jointplot(x='g-i', y='r', data=df4_stars[::100], kind='reg', xlim=(-5,5), ylim=(13,24))
sns.scatterplot(x='g-i', y='r', data=df4_stars[::100], hue="RA_PM_BINNED", ax=axs[1])
#sns.jointplot(x='g-i', y='r', data=df4_stars[::100], kind='reg', xlim=(-5,5), ylim=(13,24))
sns.scatterplot(x='g-i', y='r', data=df4_stars[::100], hue="DEC_PM_BINNED", ax=axs[2])
# Out:
# C:\Users\Pas\Miniconda3\envs\fds\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#3 panel plots
#5th 
#stars
data5_stars = {'g-i': (stars5_array[:,1] - stars5_array[:,2]), "r":stars5_array[:,0]}
df5_stars = pd.DataFrame(data = data5_stars)
df5_stars["RA_PM"] = g5_stars["RA_PM"]
df5_stars["DEC_PM"] = g5_stars["DEC_PM"]

#RA_BIN
df5_stars["RA_PM"] = g5_stars["RA_PM"]
RA_PM_BIN = []
q1 = np.quantile(df5_stars["RA_PM"], .25, axis = None)
q2 = np.quantile(df5_stars["RA_PM"], .50, axis = None)
q3 = np.quantile(df5_stars["RA_PM"], .75, axis = None)

for n in range(0,len(df5_stars["RA_PM"])):
    if (df5_stars["RA_PM"])[n] <= q1:
        RA_PM_BIN.append(1)
    elif ((df5_stars["RA_PM"])[n] > q1) and ((df5_stars["RA_PM"])[n] <= q2):
        RA_PM_BIN.append(2)
    elif ((df5_stars["RA_PM"][n]) > q2) and ((df5_stars["RA_PM"])[n] <= q3):
        RA_PM_BIN.append(3)
    else:
        RA_PM_BIN.append(4)

df5_stars["RA_PM_BINNED"] = RA_PM_BIN

#DEC_BIN
df5_stars["DEC_PM"] = g5_stars["DEC_PM"]
DEC_PM_BIN = []
q1 = np.quantile(df5_stars["DEC_PM"], .25, axis = None)
q2 = np.quantile(df5_stars["DEC_PM"], .50, axis = None)
q3 = np.quantile(df5_stars["DEC_PM"], .75, axis = None)

for n in range(0,len(df5_stars["DEC_PM"])):
    if (df5_stars["DEC_PM"])[n] <= q1:
        DEC_PM_BIN.append(1)
    elif ((df5_stars["DEC_PM"])[n] > q1) and ((df5_stars["DEC_PM"])[n] <= q2):
        DEC_PM_BIN.append(2)
    elif ((df5_stars["DEC_PM"][n]) > q2) and ((df5_stars["DEC_PM"])[n] <= q3):
        DEC_PM_BIN.append(3)
    else:
        DEC_PM_BIN.append(4)

df5_stars["DEC_PM_BINNED"] = DEC_PM_BIN

# %%
#almost got it-need to make panels bigger, incorporate bivariate with first 
#left - r vs (g-i) color coded by density + bivariate distributions
fig, axs = plt.subplots(ncols=3)
sns.jointplot(x='g-i', y='r', data=df5_stars[::100], kind='kde', color="pink", xlim=(-2,4), ylim=(14,24), ax=axs[0]).plot_joint(sns.kdeplot, zorder=0, n_levels=3, color="pink")
#middle and right-color coded by dec, ra - "RA_PM", "DEC_PM" 
#sns.jointplot(x='g-i', y='r', data=df5_stars[::100], kind='reg', xlim=(-5,5), ylim=(13,24))
sns.scatterplot(x='g-i', y='r', data=df5_stars[::100], hue="RA_PM_BINNED", ax=axs[1])
#sns.jointplot(x='g-i', y='r', data=df5_stars[::100], kind='reg', xlim=(-5,5), ylim=(13,24))
sns.scatterplot(x='g-i', y='r', data=df5_stars[::100], hue="DEC_PM_BINNED", ax=axs[2])
# Out:
# C:\Users\Pas\Miniconda3\envs\fds\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#3 panel plots
#6th 
#stars
data6_stars = {'g-i': (stars6_array[:,1] - stars6_array[:,2]), "r":stars6_array[:,0]}
df6_stars = pd.DataFrame(data = data6_stars)
df6_stars["RA_PM"] = g6_stars["RA_PM"]
df6_stars["DEC_PM"] = g6_stars["DEC_PM"]

#RA_BIN
df6_stars["RA_PM"] = g6_stars["RA_PM"]
RA_PM_BIN = []
q1 = np.quantile(df6_stars["RA_PM"], .25, axis = None)
q2 = np.quantile(df6_stars["RA_PM"], .50, axis = None)
q3 = np.quantile(df6_stars["RA_PM"], .75, axis = None)

for n in range(0,len(df6_stars["RA_PM"])):
    if (df6_stars["RA_PM"])[n] <= q1:
        RA_PM_BIN.append(1)
    elif ((df6_stars["RA_PM"])[n] > q1) and ((df6_stars["RA_PM"])[n] <= q2):
        RA_PM_BIN.append(2)
    elif ((df6_stars["RA_PM"][n]) > q2) and ((df6_stars["RA_PM"])[n] <= q3):
        RA_PM_BIN.append(3)
    else:
        RA_PM_BIN.append(4)

df6_stars["RA_PM_BINNED"] = RA_PM_BIN

#DEC_BIN
df6_stars["DEC_PM"] = g6_stars["DEC_PM"]
DEC_PM_BIN = []
q1 = np.quantile(df6_stars["DEC_PM"], .25, axis = None)
q2 = np.quantile(df6_stars["DEC_PM"], .50, axis = None)
q3 = np.quantile(df6_stars["DEC_PM"], .75, axis = None)

for n in range(0,len(df6_stars["DEC_PM"])):
    if (df6_stars["DEC_PM"])[n] <= q1:
        DEC_PM_BIN.append(1)
    elif ((df6_stars["DEC_PM"])[n] > q1) and ((df6_stars["DEC_PM"])[n] <= q2):
        DEC_PM_BIN.append(2)
    elif ((df6_stars["DEC_PM"][n]) > q2) and ((df6_stars["DEC_PM"])[n] <= q3):
        DEC_PM_BIN.append(3)
    else:
        DEC_PM_BIN.append(4)

df6_stars["DEC_PM_BINNED"] = DEC_PM_BIN

# %%
#almost got it-need to make panels bigger, incorporate bivariate with first 
#left - r vs (g-i) color coded by density + bivariate distributions
fig, axs = plt.subplots(ncols=3)
sns.jointplot(x='g-i', y='r', data=df6_stars[::100], kind='kde', color="pink", xlim=(-2,4), ylim=(14,24), ax=axs[0]).plot_joint(sns.kdeplot, zorder=0, n_levels=3, color="pink")
#middle and right-color coded by dec, ra - "RA_PM", "DEC_PM" 
#sns.jointplot(x='g-i', y='r', data=df6_stars[::100], kind='reg', xlim=(-5,5), ylim=(13,24))
sns.scatterplot(x='g-i', y='r', data=df6_stars[::100], hue="RA_PM_BINNED", ax=axs[1])
#sns.jointplot(x='g-i', y='r', data=df6_stars[::100], kind='reg', xlim=(-5,5), ylim=(13,24))
sns.scatterplot(x='g-i', y='r', data=df6_stars[::100], hue="DEC_PM_BINNED", ax=axs[2])
# Out:
# C:\Users\Pas\Miniconda3\envs\fds\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#3 panel plots
#7th 
#stars
data7_stars = {'g-i': (stars7_array[:,1] - stars7_array[:,2]), "r":stars7_array[:,0]}
df7_stars = pd.DataFrame(data = data7_stars)
df7_stars["RA_PM"] = g7_stars["RA_PM"]
df7_stars["DEC_PM"] = g7_stars["DEC_PM"]

#RA_BIN
df7_stars["RA_PM"] = g7_stars["RA_PM"]
RA_PM_BIN = []
q1 = np.quantile(df7_stars["RA_PM"], .25, axis = None)
q2 = np.quantile(df7_stars["RA_PM"], .50, axis = None)
q3 = np.quantile(df7_stars["RA_PM"], .75, axis = None)

for n in range(0,len(df7_stars["RA_PM"])):
    if (df7_stars["RA_PM"])[n] <= q1:
        RA_PM_BIN.append(1)
    elif ((df7_stars["RA_PM"])[n] > q1) and ((df7_stars["RA_PM"])[n] <= q2):
        RA_PM_BIN.append(2)
    elif ((df7_stars["RA_PM"][n]) > q2) and ((df7_stars["RA_PM"])[n] <= q3):
        RA_PM_BIN.append(3)
    else:
        RA_PM_BIN.append(4)

df7_stars["RA_PM_BINNED"] = RA_PM_BIN

#DEC_BIN
df7_stars["DEC_PM"] = g7_stars["DEC_PM"]
DEC_PM_BIN = []
q1 = np.quantile(df7_stars["DEC_PM"], .25, axis = None)
q2 = np.quantile(df7_stars["DEC_PM"], .50, axis = None)
q3 = np.quantile(df7_stars["DEC_PM"], .75, axis = None)

for n in range(0,len(df7_stars["DEC_PM"])):
    if (df7_stars["DEC_PM"])[n] <= q1:
        DEC_PM_BIN.append(1)
    elif ((df7_stars["DEC_PM"])[n] > q1) and ((df7_stars["DEC_PM"])[n] <= q2):
        DEC_PM_BIN.append(2)
    elif ((df7_stars["DEC_PM"][n]) > q2) and ((df7_stars["DEC_PM"])[n] <= q3):
        DEC_PM_BIN.append(3)
    else:
        DEC_PM_BIN.append(4)

df7_stars["DEC_PM_BINNED"] = DEC_PM_BIN

# %%
#almost got it-need to make panels bigger, incorporate bivariate with first 
#left - r vs (g-i) color coded by density + bivariate distributions
fig, axs = plt.subplots(ncols=3)
sns.jointplot(x='g-i', y='r', data=df7_stars[::100], kind='kde', color="pink", xlim=(-2,4), ylim=(14,24), ax=axs[0]).plot_joint(sns.kdeplot, zorder=0, n_levels=3, color="pink")
#middle and right-color coded by dec, ra - "RA_PM", "DEC_PM" 
#sns.jointplot(x='g-i', y='r', data=df7_stars[::100], kind='reg', xlim=(-5,5), ylim=(13,24))
sns.scatterplot(x='g-i', y='r', data=df7_stars[::100], hue="RA_PM_BINNED", ax=axs[1])
#sns.jointplot(x='g-i', y='r', data=df7_stars[::100], kind='reg', xlim=(-5,5), ylim=(13,24))
sns.scatterplot(x='g-i', y='r', data=df7_stars[::100], hue="DEC_PM_BINNED", ax=axs[2])
# Out:
# C:\Users\Pas\Miniconda3\envs\fds\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#3 panel plots
#8th 
#stars
data8_stars = {'g-i': (stars8_array[:,1] - stars8_array[:,2]), "r":stars8_array[:,0]}
df8_stars = pd.DataFrame(data = data8_stars)
df8_stars["RA_PM"] = g8_stars["RA_PM"]
df8_stars["DEC_PM"] = g8_stars["DEC_PM"]

#RA_BIN
df8_stars["RA_PM"] = g8_stars["RA_PM"]
RA_PM_BIN = []
q1 = np.quantile(df8_stars["RA_PM"], .25, axis = None)
q2 = np.quantile(df8_stars["RA_PM"], .50, axis = None)
q3 = np.quantile(df8_stars["RA_PM"], .75, axis = None)

for n in range(0,len(df8_stars["RA_PM"])):
    if (df8_stars["RA_PM"])[n] <= q1:
        RA_PM_BIN.append(1)
    elif ((df8_stars["RA_PM"])[n] > q1) and ((df8_stars["RA_PM"])[n] <= q2):
        RA_PM_BIN.append(2)
    elif ((df8_stars["RA_PM"][n]) > q2) and ((df8_stars["RA_PM"])[n] <= q3):
        RA_PM_BIN.append(3)
    else:
        RA_PM_BIN.append(4)

df8_stars["RA_PM_BINNED"] = RA_PM_BIN

#DEC_BIN
df8_stars["DEC_PM"] = df8_stars["DEC_PM"]
DEC_PM_BIN = []
q1 = np.quantile(df8_stars["DEC_PM"], .25, axis = None)
q2 = np.quantile(df8_stars["DEC_PM"], .50, axis = None)
q3 = np.quantile(df8_stars["DEC_PM"], .75, axis = None)

for n in range(0,len(df8_stars["DEC_PM"])):
    if (df8_stars["DEC_PM"])[n] <= q1:
        DEC_PM_BIN.append(1)
    elif ((df8_stars["DEC_PM"])[n] > q1) and ((df8_stars["DEC_PM"])[n] <= q2):
        DEC_PM_BIN.append(2)
    elif ((df8_stars["DEC_PM"][n]) > q2) and ((df8_stars["DEC_PM"])[n] <= q3):
        DEC_PM_BIN.append(3)
    else:
        DEC_PM_BIN.append(4)

df8_stars["DEC_PM_BINNED"] = DEC_PM_BIN

# %%
#almost got it-need to make panels bigger, incorporate bivariate with first 
#left - r vs (g-i) color coded by density + bivariate distributions
fig, axs = plt.subplots(ncols=3)
sns.jointplot(x='g-i', y='r', data=df8_stars[::100], kind='kde', color="pink", xlim=(-2,4), ylim=(14,24), ax=axs[0]).plot_joint(sns.kdeplot, zorder=0, n_levels=3, color="pink")
#middle and right-color coded by dec, ra - "RA_PM", "DEC_PM" 
#sns.jointplot(x='g-i', y='r', data=df8_stars[::100], kind='reg', xlim=(-5,5), ylim=(13,24))
sns.scatterplot(x='g-i', y='r', data=df8_stars[::100], hue="RA_PM_BINNED", ax=axs[1])
#sns.jointplot(x='g-i', y='r', data=df8_stars[::100], kind='reg', xlim=(-5,5), ylim=(13,24))
sns.scatterplot(x='g-i', y='r', data=df8_stars[::100], hue="DEC_PM_BINNED", ax=axs[2])
# Out:
# C:\Users\Pas\Miniconda3\envs\fds\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# # GALAXIES

# %%
#3 panel plots
#1st 
#galaxies
data1_galaxies = {'g-i': (galaxies1_array[:,1] - galaxies1_array[:,2]), "r":galaxies1_array[:,0]}
df1_galaxies = pd.DataFrame(data = data1_galaxies)
df1_galaxies["RA_PM"] = g1_galaxies["RA_PM"]
df1_galaxies["DEC_PM"] = g1_galaxies["DEC_PM"]

#RA_BIN
df1_galaxies["RA_PM"] = g1_galaxies["RA_PM"]
RA_PM_BIN = []
q1 = np.quantile(df1_galaxies["RA_PM"], .25, axis = None)
q2 = np.quantile(df1_galaxies["RA_PM"], .50, axis = None)
q3 = np.quantile(df1_galaxies["RA_PM"], .75, axis = None)

for n in range(0,len(df1_galaxies["RA_PM"])):
    if (df1_galaxies["RA_PM"])[n] <= q1:
        RA_PM_BIN.append(1)
    elif ((df1_galaxies["RA_PM"])[n] > q1) and ((df1_galaxies["RA_PM"])[n] <= q2):
        RA_PM_BIN.append(2)
    elif ((df1_galaxies["RA_PM"][n]) > q2) and ((df1_galaxies["RA_PM"])[n] <= q3):
        RA_PM_BIN.append(3)
    else:
        RA_PM_BIN.append(4)

df1_galaxies["RA_PM_BINNED"] = RA_PM_BIN

#DEC_BIN
df1_galaxies["DEC_PM"] = g1_galaxies["DEC_PM"]
DEC_PM_BIN = []
q1 = np.quantile(df1_galaxies["DEC_PM"], .25, axis = None)
q2 = np.quantile(df1_galaxies["DEC_PM"], .50, axis = None)
q3 = np.quantile(df1_galaxies["DEC_PM"], .75, axis = None)

for n in range(0,len(df1_galaxies["DEC_PM"])):
    if (df1_galaxies["DEC_PM"])[n] <= q1:
        DEC_PM_BIN.append(1)
    elif ((df1_galaxies["DEC_PM"])[n] > q1) and ((df1_galaxies["DEC_PM"])[n] <= q2):
        DEC_PM_BIN.append(2)
    elif ((df1_galaxies["DEC_PM"][n]) > q2) and ((df1_galaxies["DEC_PM"])[n] <= q3):
        DEC_PM_BIN.append(3)
    else:
        DEC_PM_BIN.append(4)

df1_galaxies["DEC_PM_BINNED"] = DEC_PM_BIN

# %%
#almost got it-need to make panels bigger, incorporate bivariate with first 
#left - r vs (g-i) color coded by density + bivariate distributions
fig, axs = plt.subplots(ncols=3)
sns.jointplot(x='g-i', y='r', data=df1_galaxies[::100], kind='kde', color="pink", xlim=(-5,10), ylim=(14,24), ax=axs[0]).plot_joint(sns.kdeplot, zorder=0, n_levels=3, color="pink")
#middle and right-color coded by dec, ra - "RA_PM", "DEC_PM" 
#sns.jointplot(x='g-i', y='r', data=df1_galaxies[::100], kind='reg', xlim=(-5,5), ylim=(13,24))
sns.scatterplot(x='g-i', y='r', data=df1_galaxies[::100], hue="RA_PM_BINNED", ax=axs[1])
#sns.jointplot(x='g-i', y='r', data=df1_galaxies[::100], kind='reg', xlim=(-5,5), ylim=(13,24))
sns.scatterplot(x='g-i', y='r', data=df1_galaxies[::100], hue="DEC_PM_BINNED", ax=axs[2])
# Out:
# C:\Users\Pas\Miniconda3\envs\fds\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#3 panel plots
#2nd 
#galaxies
data2_galaxies = {'g-i': (galaxies2_array[:,1] - galaxies2_array[:,2]), "r":galaxies2_array[:,0]}
df2_galaxies = pd.DataFrame(data = data2_galaxies)
df2_galaxies["RA_PM"] = g2_galaxies["RA_PM"]
df2_galaxies["DEC_PM"] = g2_galaxies["DEC_PM"]

#RA_BIN
df2_galaxies["RA_PM"] = g2_galaxies["RA_PM"]
RA_PM_BIN = []
q1 = np.quantile(df2_galaxies["RA_PM"], .25, axis = None)
q2 = np.quantile(df2_galaxies["RA_PM"], .50, axis = None)
q3 = np.quantile(df2_galaxies["RA_PM"], .75, axis = None)

for n in range(0,len(df2_galaxies["RA_PM"])):
    if (df2_galaxies["RA_PM"])[n] <= q1:
        RA_PM_BIN.append(1)
    elif ((df2_galaxies["RA_PM"])[n] > q1) and ((df2_galaxies["RA_PM"])[n] <= q2):
        RA_PM_BIN.append(2)
    elif ((df2_galaxies["RA_PM"][n]) > q2) and ((df2_galaxies["RA_PM"])[n] <= q3):
        RA_PM_BIN.append(3)
    else:
        RA_PM_BIN.append(4)

df2_galaxies["RA_PM_BINNED"] = RA_PM_BIN

#DEC_BIN
df2_galaxies["DEC_PM"] = g2_galaxies["DEC_PM"]
DEC_PM_BIN = []
q1 = np.quantile(df2_galaxies["DEC_PM"], .25, axis = None)
q2 = np.quantile(df2_galaxies["DEC_PM"], .50, axis = None)
q3 = np.quantile(df2_galaxies["DEC_PM"], .75, axis = None)

for n in range(0,len(df2_galaxies["DEC_PM"])):
    if (df2_galaxies["DEC_PM"])[n] <= q1:
        DEC_PM_BIN.append(1)
    elif ((df2_galaxies["DEC_PM"])[n] > q1) and ((df2_galaxies["DEC_PM"])[n] <= q2):
        DEC_PM_BIN.append(2)
    elif ((df2_galaxies["DEC_PM"][n]) > q2) and ((df2_galaxies["DEC_PM"])[n] <= q3):
        DEC_PM_BIN.append(3)
    else:
        DEC_PM_BIN.append(4)

df2_galaxies["DEC_PM_BINNED"] = DEC_PM_BIN

# %%
#almost got it-need to make panels bigger, incorporate bivariate with first 
#left - r vs (g-i) color coded by density + bivariate distributions
fig, axs = plt.subplots(ncols=3)
sns.jointplot(x='g-i', y='r', data=df2_galaxies[::100], kind='kde', color="pink", xlim=(-1,4), ylim=(18,24), ax=axs[0]).plot_joint(sns.kdeplot, zorder=0, n_levels=3, color="pink")
#middle and right-color coded by dec, ra - "RA_PM", "DEC_PM" 
#sns.jointplot(x='g-i', y='r', data=df2_galaxies[::100], kind='reg', xlim=(-5,5), ylim=(13,24))
sns.scatterplot(x='g-i', y='r', data=df2_galaxies[::100], hue="RA_PM_BINNED", ax=axs[1])
#sns.jointplot(x='g-i', y='r', data=df2_galaxies[::100], kind='reg', xlim=(-5,5), ylim=(13,24))
sns.scatterplot(x='g-i', y='r', data=df2_galaxies[::100], hue="DEC_PM_BINNED", ax=axs[2])
# Out:
# C:\Users\Pas\Miniconda3\envs\fds\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#3 panel plots
#3rd 
#galaxies
data3_galaxies = {'g-i': (galaxies3_array[:,1] - galaxies3_array[:,2]), "r":galaxies3_array[:,0]}
df3_galaxies = pd.DataFrame(data = data3_galaxies)
df3_galaxies["RA_PM"] = g3_galaxies["RA_PM"]
df3_galaxies["DEC_PM"] = g3_galaxies["DEC_PM"]

#RA_BIN
df3_galaxies["RA_PM"] = g3_galaxies["RA_PM"]
RA_PM_BIN = []
q1 = np.quantile(df3_galaxies["RA_PM"], .25, axis = None)
q2 = np.quantile(df3_galaxies["RA_PM"], .50, axis = None)
q3 = np.quantile(df3_galaxies["RA_PM"], .75, axis = None)

for n in range(0,len(df3_galaxies["RA_PM"])):
    if (df3_galaxies["RA_PM"])[n] <= q1:
        RA_PM_BIN.append(1)
    elif ((df3_galaxies["RA_PM"])[n] > q1) and ((df3_galaxies["RA_PM"])[n] <= q2):
        RA_PM_BIN.append(2)
    elif ((df3_galaxies["RA_PM"][n]) > q2) and ((df3_galaxies["RA_PM"])[n] <= q3):
        RA_PM_BIN.append(3)
    else:
        RA_PM_BIN.append(4)

df3_galaxies["RA_PM_BINNED"] = RA_PM_BIN

#DEC_BIN
df3_galaxies["DEC_PM"] = g3_galaxies["DEC_PM"]
DEC_PM_BIN = []
q1 = np.quantile(df3_galaxies["DEC_PM"], .25, axis = None)
q2 = np.quantile(df3_galaxies["DEC_PM"], .50, axis = None)
q3 = np.quantile(df3_galaxies["DEC_PM"], .75, axis = None)

for n in range(0,len(df3_galaxies["DEC_PM"])):
    if (df3_galaxies["DEC_PM"])[n] <= q1:
        DEC_PM_BIN.append(1)
    elif ((df3_galaxies["DEC_PM"])[n] > q1) and ((df3_galaxies["DEC_PM"])[n] <= q2):
        DEC_PM_BIN.append(2)
    elif ((df3_galaxies["DEC_PM"][n]) > q2) and ((df3_galaxies["DEC_PM"])[n] <= q3):
        DEC_PM_BIN.append(3)
    else:
        DEC_PM_BIN.append(4)

df3_galaxies["DEC_PM_BINNED"] = DEC_PM_BIN

# %%
#almost got it-need to make panels bigger, incorporate bivariate with first 
#left - r vs (g-i) color coded by density + bivariate distributions
fig, axs = plt.subplots(ncols=3)
sns.jointplot(x='g-i', y='r', data=df3_galaxies[::100], kind='kde', color="pink", xlim=(-1,4), ylim=(18,24), ax=axs[0]).plot_joint(sns.kdeplot, zorder=0, n_levels=3, color="pink")
#middle and right-color coded by dec, ra - "RA_PM", "DEC_PM" 
#sns.jointplot(x='g-i', y='r', data=df3_galaxies[::100], kind='reg', xlim=(-5,5), ylim=(13,24))
sns.scatterplot(x='g-i', y='r', data=df3_galaxies[::100], hue="RA_PM_BINNED", ax=axs[1])
#sns.jointplot(x='g-i', y='r', data=df3_galaxies[::100], kind='reg', xlim=(-5,5), ylim=(13,24))
sns.scatterplot(x='g-i', y='r', data=df3_galaxies[::100], hue="DEC_PM_BINNED", ax=axs[2])
# Out:
# C:\Users\Pas\Miniconda3\envs\fds\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#3 panel plots
#4th 
#galaxies
data4_galaxies = {'g-i': (galaxies4_array[:,1] - galaxies4_array[:,2]), "r":galaxies4_array[:,0]}
df4_galaxies = pd.DataFrame(data = data4_galaxies)
df4_galaxies["RA_PM"] = g4_galaxies["RA_PM"]
df4_galaxies["DEC_PM"] = g4_galaxies["DEC_PM"]

#RA_BIN
df4_galaxies["RA_PM"] = g4_galaxies["RA_PM"]
RA_PM_BIN = []
q1 = np.quantile(df4_galaxies["RA_PM"], .25, axis = None)
q2 = np.quantile(df4_galaxies["RA_PM"], .50, axis = None)
q3 = np.quantile(df4_galaxies["RA_PM"], .75, axis = None)

for n in range(0,len(df4_galaxies["RA_PM"])):
    if (df4_galaxies["RA_PM"])[n] <= q1:
        RA_PM_BIN.append(1)
    elif ((df4_galaxies["RA_PM"])[n] > q1) and ((df4_galaxies["RA_PM"])[n] <= q2):
        RA_PM_BIN.append(2)
    elif ((df4_galaxies["RA_PM"][n]) > q2) and ((df4_galaxies["RA_PM"])[n] <= q3):
        RA_PM_BIN.append(3)
    else:
        RA_PM_BIN.append(4)

df4_galaxies["RA_PM_BINNED"] = RA_PM_BIN

#DEC_BIN
df4_galaxies["DEC_PM"] = g4_galaxies["DEC_PM"]
DEC_PM_BIN = []
q1 = np.quantile(df4_galaxies["DEC_PM"], .25, axis = None)
q2 = np.quantile(df4_galaxies["DEC_PM"], .50, axis = None)
q3 = np.quantile(df4_galaxies["DEC_PM"], .75, axis = None)

for n in range(0,len(df4_galaxies["DEC_PM"])):
    if (df4_galaxies["DEC_PM"])[n] <= q1:
        DEC_PM_BIN.append(1)
    elif ((df4_galaxies["DEC_PM"])[n] > q1) and ((df4_galaxies["DEC_PM"])[n] <= q2):
        DEC_PM_BIN.append(2)
    elif ((df4_galaxies["DEC_PM"][n]) > q2) and ((df4_galaxies["DEC_PM"])[n] <= q3):
        DEC_PM_BIN.append(3)
    else:
        DEC_PM_BIN.append(4)

df4_galaxies["DEC_PM_BINNED"] = DEC_PM_BIN

# %%
#almost got it-need to make panels bigger, incorporate bivariate with first 
#left - r vs (g-i) color coded by density + bivariate distributions
fig, axs = plt.subplots(ncols=3)
sns.jointplot(x='g-i', y='r', data=df4_galaxies[::100], kind='kde', color="pink", xlim=(-1,4), ylim=(18,24), ax=axs[0]).plot_joint(sns.kdeplot, zorder=0, n_levels=3, color="pink")
#middle and right-color coded by dec, ra - "RA_PM", "DEC_PM" 
#sns.jointplot(x='g-i', y='r', data=df4_galaxies[::100], kind='reg', xlim=(-5,5), ylim=(13,24))
sns.scatterplot(x='g-i', y='r', data=df4_galaxies[::100], hue="RA_PM_BINNED", ax=axs[1])
#sns.jointplot(x='g-i', y='r', data=df4_galaxies[::100], kind='reg', xlim=(-5,5), ylim=(13,24))
sns.scatterplot(x='g-i', y='r', data=df4_galaxies[::100], hue="DEC_PM_BINNED", ax=axs[2])
# Out:
# C:\Users\Pas\Miniconda3\envs\fds\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#3 panel plots
#5th 
#galaxies
data5_galaxies = {'g-i': (galaxies5_array[:,1] - galaxies5_array[:,2]), "r":galaxies5_array[:,0]}
df5_galaxies = pd.DataFrame(data = data5_galaxies)
df5_galaxies["RA_PM"] = g5_galaxies["RA_PM"]
df5_galaxies["DEC_PM"] = g5_galaxies["DEC_PM"]

#RA_BIN
df5_galaxies["RA_PM"] = g5_galaxies["RA_PM"]
RA_PM_BIN = []
q1 = np.quantile(df5_galaxies["RA_PM"], .25, axis = None)
q2 = np.quantile(df5_galaxies["RA_PM"], .50, axis = None)
q3 = np.quantile(df5_galaxies["RA_PM"], .75, axis = None)

for n in range(0,len(df5_galaxies["RA_PM"])):
    if (df5_galaxies["RA_PM"])[n] <= q1:
        RA_PM_BIN.append(1)
    elif ((df5_galaxies["RA_PM"])[n] > q1) and ((df5_galaxies["RA_PM"])[n] <= q2):
        RA_PM_BIN.append(2)
    elif ((df5_galaxies["RA_PM"][n]) > q2) and ((df5_galaxies["RA_PM"])[n] <= q3):
        RA_PM_BIN.append(3)
    else:
        RA_PM_BIN.append(4)

df5_galaxies["RA_PM_BINNED"] = RA_PM_BIN

#DEC_BIN
df5_galaxies["DEC_PM"] = g5_galaxies["DEC_PM"]
DEC_PM_BIN = []
q1 = np.quantile(df5_galaxies["DEC_PM"], .25, axis = None)
q2 = np.quantile(df5_galaxies["DEC_PM"], .50, axis = None)
q3 = np.quantile(df5_galaxies["DEC_PM"], .75, axis = None)

for n in range(0,len(df5_galaxies["DEC_PM"])):
    if (df5_galaxies["DEC_PM"])[n] <= q1:
        DEC_PM_BIN.append(1)
    elif ((df5_galaxies["DEC_PM"])[n] > q1) and ((df5_galaxies["DEC_PM"])[n] <= q2):
        DEC_PM_BIN.append(2)
    elif ((df5_galaxies["DEC_PM"][n]) > q2) and ((df5_galaxies["DEC_PM"])[n] <= q3):
        DEC_PM_BIN.append(3)
    else:
        DEC_PM_BIN.append(4)

df5_galaxies["DEC_PM_BINNED"] = DEC_PM_BIN

# %%
#almost got it-need to make panels bigger, incorporate bivariate with first 
#left - r vs (g-i) color coded by density + bivariate distributions
fig, axs = plt.subplots(ncols=3)
sns.jointplot(x='g-i', y='r', data=df5_galaxies[::100], kind='kde', color="pink", xlim=(-1,4), ylim=(18,24), ax=axs[0]).plot_joint(sns.kdeplot, zorder=0, n_levels=3, color="pink")
#middle and right-color coded by dec, ra - "RA_PM", "DEC_PM" 
#sns.jointplot(x='g-i', y='r', data=df5_galaxies[::100], kind='reg', xlim=(-5,5), ylim=(13,24))
sns.scatterplot(x='g-i', y='r', data=df5_galaxies[::100], hue="RA_PM_BINNED", ax=axs[1])
#sns.jointplot(x='g-i', y='r', data=df5_galaxies[::100], kind='reg', xlim=(-5,5), ylim=(13,24))
sns.scatterplot(x='g-i', y='r', data=df5_galaxies[::100], hue="DEC_PM_BINNED", ax=axs[2])
# Out:
# C:\Users\Pas\Miniconda3\envs\fds\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#3 panel plots
#6th 
#galaxies
data6_galaxies = {'g-i': (galaxies6_array[:,1] - galaxies6_array[:,2]), "r":galaxies6_array[:,0]}
df6_galaxies = pd.DataFrame(data = data6_galaxies)
df6_galaxies["RA_PM"] = g6_galaxies["RA_PM"]
df6_galaxies["DEC_PM"] = g6_galaxies["DEC_PM"]

#RA_BIN
df6_galaxies["RA_PM"] = g6_galaxies["RA_PM"]
RA_PM_BIN = []
q1 = np.quantile(df6_galaxies["RA_PM"], .25, axis = None)
q2 = np.quantile(df6_galaxies["RA_PM"], .50, axis = None)
q3 = np.quantile(df6_galaxies["RA_PM"], .75, axis = None)

for n in range(0,len(df6_galaxies["RA_PM"])):
    if (df6_galaxies["RA_PM"])[n] <= q1:
        RA_PM_BIN.append(1)
    elif ((df6_galaxies["RA_PM"])[n] > q1) and ((df6_galaxies["RA_PM"])[n] <= q2):
        RA_PM_BIN.append(2)
    elif ((df6_galaxies["RA_PM"][n]) > q2) and ((df6_galaxies["RA_PM"])[n] <= q3):
        RA_PM_BIN.append(3)
    else:
        RA_PM_BIN.append(4)

df6_galaxies["RA_PM_BINNED"] = RA_PM_BIN

#DEC_BIN
df6_galaxies["DEC_PM"] = g6_galaxies["DEC_PM"]
DEC_PM_BIN = []
q1 = np.quantile(df6_galaxies["DEC_PM"], .25, axis = None)
q2 = np.quantile(df6_galaxies["DEC_PM"], .50, axis = None)
q3 = np.quantile(df6_galaxies["DEC_PM"], .75, axis = None)

for n in range(0,len(df6_galaxies["DEC_PM"])):
    if (df6_galaxies["DEC_PM"])[n] <= q1:
        DEC_PM_BIN.append(1)
    elif ((df6_galaxies["DEC_PM"])[n] > q1) and ((df6_galaxies["DEC_PM"])[n] <= q2):
        DEC_PM_BIN.append(2)
    elif ((df6_galaxies["DEC_PM"][n]) > q2) and ((df6_galaxies["DEC_PM"])[n] <= q3):
        DEC_PM_BIN.append(3)
    else:
        DEC_PM_BIN.append(4)

df6_galaxies["DEC_PM_BINNED"] = DEC_PM_BIN

# %%
#almost got it-need to make panels bigger, incorporate bivariate with first 
#left - r vs (g-i) color coded by density + bivariate distributions
fig, axs = plt.subplots(ncols=3)
sns.jointplot(x='g-i', y='r', data=df6_galaxies[::100], kind='kde', color="pink", xlim=(-1,4), ylim=(18,24), ax=axs[0]).plot_joint(sns.kdeplot, zorder=0, n_levels=3, color="pink")
#middle and right-color coded by dec, ra - "RA_PM", "DEC_PM" 
#sns.jointplot(x='g-i', y='r', data=df6_galaxies[::100], kind='reg', xlim=(-5,5), ylim=(13,24))
sns.scatterplot(x='g-i', y='r', data=df6_galaxies[::100], hue="RA_PM_BINNED", ax=axs[1])
#sns.jointplot(x='g-i', y='r', data=df6_galaxies[::100], kind='reg', xlim=(-5,5), ylim=(13,24))
sns.scatterplot(x='g-i', y='r', data=df6_galaxies[::100], hue="DEC_PM_BINNED", ax=axs[2])
# Out:
# C:\Users\Pas\Miniconda3\envs\fds\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#3 panel plots
#7th 
#galaxies
data7_galaxies = {'g-i': (galaxies7_array[:,1] - galaxies7_array[:,2]), "r":galaxies7_array[:,0]}
df7_galaxies = pd.DataFrame(data = data7_galaxies)
df7_galaxies["RA_PM"] = g7_galaxies["RA_PM"]
df7_galaxies["DEC_PM"] = g7_galaxies["DEC_PM"]

#RA_BIN
df7_galaxies["RA_PM"] = g7_galaxies["RA_PM"]
RA_PM_BIN = []
q1 = np.quantile(df7_galaxies["RA_PM"], .25, axis = None)
q2 = np.quantile(df7_galaxies["RA_PM"], .50, axis = None)
q3 = np.quantile(df7_galaxies["RA_PM"], .75, axis = None)

for n in range(0,len(df7_galaxies["RA_PM"])):
    if (df7_galaxies["RA_PM"])[n] <= q1:
        RA_PM_BIN.append(1)
    elif ((df7_galaxies["RA_PM"])[n] > q1) and ((df7_galaxies["RA_PM"])[n] <= q2):
        RA_PM_BIN.append(2)
    elif ((df7_galaxies["RA_PM"][n]) > q2) and ((df7_galaxies["RA_PM"])[n] <= q3):
        RA_PM_BIN.append(3)
    else:
        RA_PM_BIN.append(4)

df7_galaxies["RA_PM_BINNED"] = RA_PM_BIN

#DEC_BIN
df7_galaxies["DEC_PM"] = g7_galaxies["DEC_PM"]
DEC_PM_BIN = []
q1 = np.quantile(df7_galaxies["DEC_PM"], .25, axis = None)
q2 = np.quantile(df7_galaxies["DEC_PM"], .50, axis = None)
q3 = np.quantile(df7_galaxies["DEC_PM"], .75, axis = None)

for n in range(0,len(df7_galaxies["DEC_PM"])):
    if (df7_galaxies["DEC_PM"])[n] <= q1:
        DEC_PM_BIN.append(1)
    elif ((df7_galaxies["DEC_PM"])[n] > q1) and ((df7_galaxies["DEC_PM"])[n] <= q2):
        DEC_PM_BIN.append(2)
    elif ((df7_galaxies["DEC_PM"][n]) > q2) and ((df7_galaxies["DEC_PM"])[n] <= q3):
        DEC_PM_BIN.append(3)
    else:
        DEC_PM_BIN.append(4)

df7_galaxies["DEC_PM_BINNED"] = DEC_PM_BIN

# %%
#almost got it-need to make panels bigger, incorporate bivariate with first 
#left - r vs (g-i) color coded by density + bivariate distributions
fig, axs = plt.subplots(ncols=3)
sns.jointplot(x='g-i', y='r', data=df7_galaxies[::100], kind='kde', color="pink", xlim=(-1,4), ylim=(18,24), ax=axs[0]).plot_joint(sns.kdeplot, zorder=0, n_levels=3, color="pink")
#middle and right-color coded by dec, ra - "RA_PM", "DEC_PM" 
#sns.jointplot(x='g-i', y='r', data=df7_galaxies[::100], kind='reg', xlim=(-5,5), ylim=(13,24))
sns.scatterplot(x='g-i', y='r', data=df7_galaxies[::100], hue="RA_PM_BINNED", ax=axs[1])
#sns.jointplot(x='g-i', y='r', data=df7_galaxies[::100], kind='reg', xlim=(-5,5), ylim=(13,24))
sns.scatterplot(x='g-i', y='r', data=df7_galaxies[::100], hue="DEC_PM_BINNED", ax=axs[2])
# Out:
# C:\Users\Pas\Miniconda3\envs\fds\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#3 panel plots
#8th 
#galaxies
data8_galaxies = {'g-i': (galaxies8_array[:,1] - galaxies8_array[:,2]), "r":galaxies8_array[:,0]}
df8_galaxies = pd.DataFrame(data = data8_galaxies)
df8_galaxies["RA_PM"] = g8_galaxies["RA_PM"]
df8_galaxies["DEC_PM"] = g8_galaxies["DEC_PM"]

#RA_BIN
df8_galaxies["RA_PM"] = g8_galaxies["RA_PM"]
RA_PM_BIN = []
q1 = np.quantile(df8_galaxies["RA_PM"], .25, axis = None)
q2 = np.quantile(df8_galaxies["RA_PM"], .50, axis = None)
q3 = np.quantile(df8_galaxies["RA_PM"], .75, axis = None)

for n in range(0,len(df8_galaxies["RA_PM"])):
    if (df8_galaxies["RA_PM"])[n] <= q1:
        RA_PM_BIN.append(1)
    elif ((df8_galaxies["RA_PM"])[n] > q1) and ((df8_galaxies["RA_PM"])[n] <= q2):
        RA_PM_BIN.append(2)
    elif ((df8_galaxies["RA_PM"][n]) > q2) and ((df8_galaxies["RA_PM"])[n] <= q3):
        RA_PM_BIN.append(3)
    else:
        RA_PM_BIN.append(4)

df8_galaxies["RA_PM_BINNED"] = RA_PM_BIN

#DEC_BIN
df8_galaxies["DEC_PM"] = g8_galaxies["DEC_PM"]
DEC_PM_BIN = []
q1 = np.quantile(df8_galaxies["DEC_PM"], .25, axis = None)
q2 = np.quantile(df8_galaxies["DEC_PM"], .50, axis = None)
q3 = np.quantile(df8_galaxies["DEC_PM"], .75, axis = None)

for n in range(0,len(df8_galaxies["DEC_PM"])):
    if (df8_galaxies["DEC_PM"])[n] <= q1:
        DEC_PM_BIN.append(1)
    elif ((df8_galaxies["DEC_PM"])[n] > q1) and ((df8_galaxies["DEC_PM"])[n] <= q2):
        DEC_PM_BIN.append(2)
    elif ((df8_galaxies["DEC_PM"][n]) > q2) and ((df8_galaxies["DEC_PM"])[n] <= q3):
        DEC_PM_BIN.append(3)
    else:
        DEC_PM_BIN.append(4)

df8_galaxies["DEC_PM_BINNED"] = DEC_PM_BIN

# %%
#almost got it-need to make panels bigger, incorporate bivariate with first 
#left - r vs (g-i) color coded by density + bivariate distributions
fig, axs = plt.subplots(ncols=3)
sns.jointplot(x='g-i', y='r', data=df8_galaxies[::100], kind='kde', color="pink", xlim=(-1,4), ylim=(18,24), ax=axs[0]).plot_joint(sns.kdeplot, zorder=0, n_levels=3, color="pink")
#middle and right-color coded by dec, ra - "RA_PM", "DEC_PM" 
#sns.jointplot(x='g-i', y='r', data=df8_galaxies[::100], kind='reg', xlim=(-5,5), ylim=(13,24))
sns.scatterplot(x='g-i', y='r', data=df8_galaxies[::100], hue="RA_PM_BINNED", ax=axs[1])
#sns.jointplot(x='g-i', y='r', data=df8_galaxies[::100], kind='reg', xlim=(-5,5), ylim=(13,24))
sns.scatterplot(x='g-i', y='r', data=df8_galaxies[::100], hue="DEC_PM_BINNED", ax=axs[2])
# Out:
# C:\Users\Pas\Miniconda3\envs\fds\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# It seems that the largest density of stars seems to be mostly centered around a g-i range of [0,5] and an r range of [15,24].
# For the galaxies, the densities is mostly around g-i of [0,3] and r values of [20,23]. Thus stars tend to span a larger range of
# values more equally for both quantities than do galaxies.
# As for the HLCs, it seems that for the HLC 1,2,3,4 and 8, the 3 levels of density for galaxies are more evenly distributed.
# This changes for HLC 4,5, and 6, where the highest level of galaxies are clustered in a very small area.This observation doesn't
# completely line up with the observations of stars, whose HLC values and density properties do not necessarily line up with their
# galaxy counterparts.
# Yet all of the HLCs have a similar distribution for galaxies and stars except for that of HLC 1.
# I presume that the larger and more even spread in stars in galaxies is due to a more evolved galaxy consisting of older stars and
# smaller (if not completely nonexistent) places of star formation.

# %% [markdown]
# # Question 2

# %%
#read in data
dat = pd.read_csv("C:/Users/Pas/ast596_2020_Spring/data/01/IntroStat_demo.csv")
dat.columns
# Out:
# Index(['time', 'mag.hom', 'mag.outlier', 'mag.t', 'mag.het', 'mag.het.error',
#        'mag5', 'mag5.error'],
#       dtype='object')

# %%
#calculate sample mean and variance and plot
sample_mean_out  = np.mean(dat["mag.outlier"])
sample_var_out   = (np.std(dat["mag.outlier"]))**2

#plot
sm.qqplot(dat["mag.outlier"], line='s')

# %%
#calculate first and third quantiles
q1 = np.quantile(dat["mag.outlier"], .25, axis = None)
q1 = float(q1)
q3 = np.quantile(dat["mag.outlier"], .75, axis = None)
q3 = float(q3)
#x-values - time corresponding to quartiles?
x1 = len(np.array(dat["mag.outlier"]))/4
x2 = len(np.array(dat["mag.outlier"]))*.75
#create eqn of line
m = (q3-q1)/(x2-x1)
b = q1-m*x1
#plot on data
plt.scatter(dat["time"],dat["mag.outlier"])
plt.plot(dat["time"], (m*dat["time"]+b), c= "red", marker='.', linestyle=':')

# %% [markdown]
# # repeat with mag.het

# %%
#calculate sample mean and variance and plot
sample_mean_het  = np.mean(dat["mag.het"])
sample_var_het   = (np.std(dat["mag.het"]))**2

#plot
sm.qqplot(dat["mag.het"], line='s')

# %%
#calculate first and third quantiles
q1 = np.quantile(dat["mag.het"], .25, axis = None)
q1 = float(q1)
q3 = np.quantile(dat["mag.het"], .75, axis = None)
q3 = float(q3)
#x-values - time corresponding to quartiles?
x1 = len(np.array(dat["mag.het"]))/4
x2 = len(np.array(dat["mag.het"]))*.75
#create eqn of line
m = (q3-q1)/(x2-x1)
b = q1-m*x1
#plot on data
plt.scatter(dat["time"],dat["mag.het"])
plt.plot(dat["time"], (m*dat["time"]+b), c= "red", marker='.', linestyle=':')

# %% [markdown]
# It seems that the model we created using the 2 quartiles works better to predict mag.outliers as opposed to mag.het.
# I think this makes sense, as outliers are more deviant and unpredictable.

# %%
#rescale data and plot
sm.qqplot(((dat["mag.het"] - sample_mean_het)/dat["mag.het.error"]), line='s')

# %% [markdown]
# You are normalizing the data by subtracting the mean and dividing by the error. Thus, this means that the scaled data will appear to
# line up better with the QQplot, which measures the normality of a sample.

# %% [markdown]
# # Question 3

# %%
#read in data
cepheids = pd.read_csv("C:/Users/Pas/ast596_2020_Spring/data/01/Cepheids.csv")

# %%
LMC = (cepheids)[(cepheids["Cloud"]) == "LMC"]
SMC = (cepheids)[(cepheids["Cloud"]) == "SMC"]
LMC_F = LMC[LMC["Mode"] == "F"]
LMC_1 = LMC[LMC["Mode"] == "1"]
SMC_F = SMC[SMC["Mode"] == "F"]
SMC_1 = SMC[SMC["Mode"] == "1"]

# %%
#Fit straight line on all of these
slopeLF, interceptLF = linregress(LMC_F["logP1"], LMC_F["W"])[0:2]
#LMC_F
plt.plot(LMC_F["logP1"], LMC_F["W"], 'ro')
plt.plot(LMC_F["logP1"], (slopeLF*LMC_F["logP1"]+interceptLF))

# %%
#Fit straight line on all of these
slopeL1, interceptL1 = linregress(LMC_1["logP1"], LMC_1["W"])[0:2]
#LMC_1
plt.plot(LMC_1["logP1"], LMC_1["W"], 'ro')
plt.plot(LMC_1["logP1"], (slopeL1*LMC_1["logP1"]+interceptL1))

# %%
#Fit straight line on all of these
slopeSF, interceptSF = linregress(SMC_F["logP1"], SMC_F["W"])[0:2]
#SMC_F
plt.plot(SMC_F["logP1"], SMC_F["W"], 'ro')
plt.plot(SMC_F["logP1"], (slopeSF*SMC_F["logP1"]+interceptSF))

# %%
#Fit straight line on all of these
slopeS1, interceptS1 = linregress(SMC_1["logP1"], SMC_1["W"])[0:2]
#SMC_1
plt.plot(SMC_1["logP1"], SMC_1["W"], 'ro')
plt.plot(SMC_1["logP1"], (slopeS1*SMC_1["logP1"]+interceptS1))

# %%
#Compute and plot residuals of each sample to respective fitted line
#LMC_F
resid_LF = LMC_F["W"] - (slopeLF*LMC_F["logP1"]+interceptLF)
fig, axs = plt.subplots(4)
sns.distplot(resid_LF, ax=axs[0]);
#LMC_1
resid_L1 = LMC_1["W"] - (slopeL1*LMC_1["logP1"]+interceptL1)
sns.distplot(resid_L1, ax=axs[1]);
#SMC_F
resid_SF = SMC_F["W"] - (slopeSF*SMC_F["logP1"]+interceptSF)
sns.distplot(resid_SF, ax=axs[2]);
#SMC_1
resid_S1 = SMC_1["W"] - (slopeS1*SMC_1["logP1"]+interceptS1)
sns.distplot(resid_S1, ax=axs[3]);
# Out:
# C:\Users\Pas\Miniconda3\envs\fds\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# Does this look like normal distribution?
# Yes, the residuals of W do seem to follow a normal distribution. I think that this is due to cepheid variables having variable
# measured luminosities that directly correspond to their periods. With their immense variability and considering the large sample
# size of this dataset, then the distribution will be roughly normal.

# %%
LMC_F.columns
# Out:
# Index(['name', 'RA0', 'Decl0', 'Mode', 'Cloud', 'W', 'logP1', 'VI'], dtype='object')

# %%
#Plot the residuals color coded by if they are positive or negative vs RA and Dec
#LMC F
data_LF = {"W" : LMC_F["W"], 'residuals': resid_LF, "RA": LMC_F["RA0"], "DEC": LMC_F["Decl0"]}
df_LF = pd.DataFrame(data_LF)
RES_LF_SIGN = []
for n in range(0,len(data_LF['residuals'])):
    if data_LF['residuals'][n] > 0:
        RES_LF_SIGN.append(1)
    else:
        RES_LF_SIGN.append(0)
df_LF["RES_LF_SIGN"] = RES_LF_SIGN
fig, axs = plt.subplots(ncols=2)
sns.scatterplot(x='RA', y='residuals', data=df_LF, hue="RES_LF_SIGN", ax=axs[0])
sns.scatterplot(x='DEC', y='residuals', data=df_LF, hue="RES_LF_SIGN", ax=axs[1])

# %%
#Plot the residuals color coded by if they are positive or negative vs RA and Dec
#LMC 1
data_L1 = {"W" : LMC_1["W"], 'residuals': resid_L1, "RA": LMC_1["RA0"], "DEC": LMC_1["Decl0"]}
df_L1 = pd.DataFrame(data_L1)
RES_L1_SIGN = []
for n in range(0,len(df_L1['residuals'])):
    if df_L1['residuals'].iloc[n] > 0:
        RES_L1_SIGN.append(1)
    else:
        RES_L1_SIGN.append(0)
df_L1["RES_L1_SIGN"] = RES_L1_SIGN
fig, axs = plt.subplots(ncols=2)
sns.scatterplot(x='RA', y='residuals', data=df_L1, hue="RES_L1_SIGN", ax=axs[0])
sns.scatterplot(x='DEC', y='residuals', data=df_L1, hue="RES_L1_SIGN", ax=axs[1])

# %%
#Plot the residuals color coded by if they are positive or negative vs RA and Dec
#SMC F
data_SF = {"W" : SMC_F["W"], 'residuals': resid_SF, "RA": SMC_F["RA0"], "DEC": SMC_F["Decl0"]}
df_SF = pd.DataFrame(data_SF)
RES_SF_SIGN = []
for n in range(0,len(df_SF['residuals'])):
    if df_SF['residuals'].iloc[n] > 0:
        RES_SF_SIGN.append(1)
    else:
        RES_SF_SIGN.append(0)
df_SF["RES_SF_SIGN"] = RES_SF_SIGN
fig, axs = plt.subplots(ncols=2)
sns.scatterplot(x='RA', y='residuals', data=df_SF, hue="RES_SF_SIGN", ax=axs[0])
sns.scatterplot(x='DEC', y='residuals', data=df_SF, hue="RES_SF_SIGN", ax=axs[1])

# %%
#Plot the residuals color coded by if they are positive or negative vs RA and Dec
#SMC 1
data_S1 = {"W" : SMC_1["W"], 'residuals': resid_S1, "RA": SMC_1["RA0"], "DEC": SMC_1["Decl0"]}
df_S1 = pd.DataFrame(data_S1)
RES_S1_SIGN = []
for n in range(0,len(df_S1['residuals'])):
    if df_S1['residuals'].iloc[n] > 0:
        RES_S1_SIGN.append(1)
    else:
        RES_S1_SIGN.append(0)
df_S1["RES_S1_SIGN"] = RES_S1_SIGN
fig, axs = plt.subplots(ncols=2)
sns.scatterplot(x='RA', y='residuals', data=df_S1, hue="RES_S1_SIGN", ax=axs[0])
sns.scatterplot(x='DEC', y='residuals', data=df_S1, hue="RES_S1_SIGN", ax=axs[1])

# %%
#plot the residuals against the fitted W values
#LMC F
plt.plot((slopeLF*LMC_F["logP1"]+interceptLF), resid_LF, 'ro')

# %%
#plot the residuals against the fitted W values
#LMC 1
plt.plot((slopeL1*LMC_1["logP1"]+interceptL1), resid_L1, 'ro')

# %%
#plot the residuals against the fitted W values
#SMC F
plt.plot((slopeSF*SMC_F["logP1"]+interceptSF), resid_SF, 'ro')

# %%
#plot the residuals against the fitted W values
#SMC 1
plt.plot((slopeS1*SMC_1["logP1"]+interceptS1), resid_S1, 'ro')

# %%
#plot log(P1) vs V-I
#LMC F
plt.plot(LMC_F["VI"], LMC_F["logP1"], 'ro')

# %%
#plot log(P1) vs V-I
#LMC 1
plt.plot(LMC_1["VI"], LMC_1["logP1"], 'ro')

# %%
#plot log(P1) vs V-I
#SMC F
plt.plot(SMC_F["VI"], SMC_F["logP1"], 'ro')

# %%
#plot log(P1) vs V-I
#SMC 1
plt.plot(SMC_1["VI"], SMC_1["logP1"], 'ro')

# %% [markdown]
# There seems to be a fairly even spread in the positive and negative residuals vs. RA and DEC for each of the 4 subsets that we plotted.
# The relationship for the fitted W values and the residual values seems fairly horizontal, thus indiating that our assumption of
# using a linear model to predict the W values was fairly accurate.
# There seems to be a positive relationship betwen "v-i" and "logP1" for these subsets. This relationship could probably be estimated
# using a linear model as well.
